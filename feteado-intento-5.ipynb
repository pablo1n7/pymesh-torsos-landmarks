# %%
import pymesh
import numpy as np
import pandas as pd
import math
import glob
import re

def distance3D(a, b):
    return math.sqrt((a[0]-b[0])**2+(a[1]-b[1])**2+(a[2]-b[2])**2)

def distance2D(a, b):
        return math.sqrt( ((b[0]-a[0])**2)  + ((b[1]-a[1])**2) )



fs_landmarks = sorted(glob.glob("../../Datos/data_artificial_cites/landmarks_reales/*.pts"))
fs_mesh = sorted(glob.glob("./out/torsos_smooth/*.ply"))

if np.shape(fs_landmarks) != np.shape(fs_mesh):
    print "No son iguales"

#fs_mesh[0]

for landmarks_f, mesh_f in zip(fs_landmarks[10:], fs_mesh[10:]):
    #mesh_f = fs_mesh[0]
    #landmarks_f = fs_landmarks[0] 
    print mesh_f+"  "+landmarks_f
    landmarks = pd.read_csv(landmarks_f,header=None,index_col=[0],skiprows=range(2),delimiter=r"\s+")
    mesh = pymesh.load_mesh(mesh_f)
    ls0 = landmarks.iloc[0].tolist()
    ls1 = landmarks.iloc[4].tolist()
    ls2 = landmarks.iloc[9].tolist()
    ls3 = landmarks.iloc[10].tolist()
    head = landmarks.iloc[14].tolist()
    #foot_left = landmarks.iloc[7].tolist()
    #foot_right = landmarks.iloc[6].tolist()
    knee_left = landmarks.iloc[8].tolist()
    knee_right = landmarks.iloc[5].tolist()

    alpha = -(math.pi /8)
    
    #alpha = (math.pi /12)
    #alpha = math.radians(5)
    #alpha = math.radians(3) 
    ids_1 = ["025","026","061","065","067","070","073","078","079","080","081","085","086","090","097","094"]
    ids_2 = ["002","034","064","071","087","088","092","098"]
    ids_3 = ["005","033","048","051","114","137","138","145"]
    
    if(re.findall(r'\d+', mesh_f)[0] in ids_1):
        alpha = alpha - (math.pi /12)
    if(re.findall(r'\d+', mesh_f)[0] in ids_2):
        alpha = alpha - math.radians(5)
    if(re.findall(r'\d+', mesh_f)[0] in ids_3):
        alpha = alpha - math.radians(3)
    
    #matrix = [[1,0,0],[0,math.cos(alpha),-math.sin(alpha)],[0,math.sin(alpha),math.cos(alpha)],[0,0,0]]
    matrix = [[1,0,0,0],[0,math.cos(alpha),-math.sin(alpha),0],[0,math.sin(alpha),math.cos(alpha),0],[0,0,0,1]]   

    ls0 = np.dot(matrix,[ls0[0],ls0[1],ls0[2],1])[:-1] 
    ls3 = np.dot(matrix,[ls3[0],ls3[1],ls3[2],1])[:-1] 

    ls1 = np.dot(matrix,[ls1[0],ls1[1],ls1[2],1])[:-1] 
    ls2 = np.dot(matrix,[ls2[0],ls2[1],ls2[2],1])[:-1] 

    head = np.dot(matrix,[head[0],head[1],head[2],1])[:-1] 
    knee_left = np.dot(matrix,[knee_left[0],knee_left[1],knee_left[2],1])[:-1] 
    knee_right = np.dot(matrix,[knee_right[0],knee_right[1],knee_right[2],1])[:-1] 

    center_knee = np.array([knee_left,knee_right]).mean(0)
    semi_landmark = np.array([ls1,ls2]).mean(0)
    distancias = []
    for v in mesh.vertices:
        distancias.append(distance3D(semi_landmark,v))
    distancias = np.array(distancias)
    centro = mesh.vertices[distancias.argmin()]
    distancias.argmin()

    d = pymesh.meshutils.generate_icosphere(0.01,centro)
    pymesh.save_mesh("out/landk.ply", d)

    semi_landmark_superior = np.array([ls0,ls3]).mean(0)
    distancias = []
    for v in mesh.vertices:
        distancias.append(distance3D(semi_landmark_superior,v))
    distancias = np.array(distancias)
    centro_superior = mesh.vertices[distancias.argmin()]

    d = pymesh.meshutils.generate_icosphere(0.01,centro_superior)
    pymesh.save_mesh("out/landk-s.ply", d)

    def lamina_corte(_centro):
        delta = [0.4,0.0003,0.4]
        xdot = (head[0]*center_knee[0] + head[1]*center_knee[1] + head[2]*center_knee[2])
        norma = math.sqrt(head[0]**2+head[1]**2+head[2]**2) * math.sqrt(center_knee[0]**2+center_knee[1]**2+center_knee[2]**2)
        angle_head = (math.cos(xdot/norma) ** -1)
        angle_head_r = math.radians(90 - math.degrees(angle_head))
        q = pymesh.misc.Quaternion(quat=[1,-angle_head_r, 0,0])
        p1 = _centro + delta
        p2 = _centro  -  delta
        return pymesh.meshutils.generate_box_mesh(p2,p1 ,1)



    #matrix_translate = [[1,0,0,0],[0,1,0,0.02],[0,0,1,0],[0,0,0,1]]

    #for i,v in enumerate(c.vertices_ref):
        #c.vertices_ref[i] = np.dot(matrix,[v[0],v[1],v[2],1])[:-1] 
        #c.vertices_ref[i] = np.dot(matrix,v)[:-1] 


    c = lamina_corte(centro_superior)
    pymesh.save_mesh("out/fetas/{}-feta-{}.ply".format(-1,mesh_f.split("/")[-1]),c)
    #new_mesh = c

    c = lamina_corte(centro)
    pymesh.save_mesh("out/fetas/{}-feta-{}.ply".format(0,mesh_f.split("/")[-1]),c)




    dist = distance2D(centro,centro_superior) / 98
    dist

    matrix_translate = [[1,0,0,0],[0,1,0,dist],[0,0,1,0],[0,0,0,1]]

    for j in range(1,98):
        for i,v in enumerate(c.vertices_ref):
            c.vertices_ref[i] = np.dot(matrix_translate,[v[0],v[1],v[2],1])[:-1] 
            #c.vertices_ref[i] = np.dot(matrix,v)[:-1] 
            #new_mesh = pymesh.boolean(new_mesh, c , operation="union",engine="auto")
        pymesh.save_mesh("out/fetas/{}-feta-{}.ply".format(j,mesh_f.split("/")[-1]), c)

    new_mesh = pymesh.load_mesh("out/fetas/{}-feta-{}.ply".format(0,mesh_f.split("/")[-1]))
    for i in range(1,50):
        temp= pymesh.load_mesh("out/fetas/{}-feta-{}.ply".format(i,mesh_f.split("/")[-1]))
        new_mesh = pymesh.boolean(new_mesh, temp , operation="union",engine="auto")

    output_mesh = pymesh.boolean(new_mesh, mesh, operation="intersection",engine="auto")
    #pymesh.save_mesh("out/torsos_feteados/feteado-{}".format(mesh_f.split("/")[-1]), output_mesh)
    pymesh.save_mesh("out/torsos_feteados/feteado-{}".format(mesh_f.split("/")[-1]), output_mesh)
    print "----------------------------------------------------------"
# Out:
# ./out/torsos_smooth/model_mesh_015.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_015.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_016.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_016.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_017.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_017.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_018.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_018.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_019.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_019.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_020.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_020.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_021.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_021.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_024.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_024.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_025.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_025.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_026.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_026.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_028.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_028.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_030.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_030.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_033.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_033.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_034.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_034.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_035.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_035.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_036.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_036.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_038.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_038.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_039.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_039.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_041.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_041.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_042.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_042.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_043.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_043.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_044.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_044.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_045.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_045.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_046.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_046.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_047.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_047.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_048.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_048.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_049.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_049.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_050.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_050.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_051.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_051.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_052.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_052.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_053.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_053.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_054.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_054.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_055.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_055.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_056.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_056.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_058.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_058.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_059.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_059.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_061.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_061.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_062.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_062.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_063.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_063.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_064.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_064.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_065.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_065.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_067.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_067.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_069.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_069.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_070.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_070.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_071.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_071.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_073.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_073.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_074.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_074.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_075.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_075.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_076.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_076.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_078.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_078.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_079.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_079.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_080.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_080.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_081.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_081.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_082.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_082.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_084.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_084.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_085.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_085.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_086.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_086.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_087.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_087.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_088.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_088.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_089.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_089.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_090.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_090.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_091.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_091.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_092.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_092.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_094.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_094.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_097.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_097.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_098.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_098.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_100.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_100.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_101.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_101.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_103.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_103.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_104.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_104.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_105.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_105.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_106.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_106.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_107.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_107.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_108.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_108.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_110.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_110.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_112.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_112.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_113.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_113.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_114.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_114.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_115.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_115.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_117.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_117.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_118.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_118.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_120.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_120.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_121.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_121.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_122.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_122.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_123.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_123.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_124.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_124.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_125.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_125.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_127.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_127.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_128.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_128.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_130.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_130.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_135.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_135.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_136.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_136.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_137.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_137.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_138.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_138.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_139.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_139.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_141.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_141.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_142.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_142.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_143.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_143.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_145.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_145.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_146.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_146.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_147.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_147.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_148.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_148.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_149.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_149.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_150.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_150.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_151.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_151.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_153.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_153.pts
# ----------------------------------------------------------
# ./out/torsos_smooth/model_mesh_154.ply  ../../Datos/data_artificial_cites/landmarks_reales/model_mesh_154.pts
# ----------------------------------------------------------
