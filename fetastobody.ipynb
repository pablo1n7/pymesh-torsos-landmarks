# %%
import numpy as np
import pymesh
from glob import glob
import math
import re

# %%
fs_mesh = np.array(sorted(glob("./out/torsos_smooth/*.ply")))

# %%
for mesh_f in fs_mesh[0:5]:
    print mesh_f
    if mesh_f == "./out/torsos_smooth/model_mesh_067.ply" or mesh_f == "./out/torsos_smooth/model_mesh_062.ply" or mesh_f == "./out/torsos_smooth/model_mesh_076.ply" or mesh_f == "./out/torsos_smooth/model_mesh_108.ply" or  mesh_f == "./out/torsos_smooth/model_mesh_149.ply":
        print("omitido")
        continue
        
    #ids.append(re.findall(r'\d+',mesh_f)[0])
    fetas_i = [str(i)+"-feta-"+mesh_f.split("/")[-1]+".ply" for i in range(0,251)]
    #mesh_torso = pymesh.load_mesh(mesh_f) 
    medidas = []
    fetas_i.reverse()
    mesh_completo = pymesh.load_mesh("./out_energy/landmarks/fetas/"+fetas_i[0])
    for f in fetas_i[1:]:
        print f
        mesh = pymesh.load_mesh("./out_energy/landmarks/fetas/"+f)
        mesh_completo = pymesh.boolean(mesh_completo, mesh , operation="union",engine="auto")
        del mesh
    
    pymesh.save_mesh("out_energy/landmarks/cuerpos_feteados/feteado-{}".format(mesh_f.split("/")[-1]), mesh_completo)
# Out:
# ./out/torsos_smooth/model_mesh_001.ply
# 249-feta-model_mesh_001.ply.ply
# 248-feta-model_mesh_001.ply.ply
# 247-feta-model_mesh_001.ply.ply
# 246-feta-model_mesh_001.ply.ply
# 245-feta-model_mesh_001.ply.ply
# 244-feta-model_mesh_001.ply.ply
# 243-feta-model_mesh_001.ply.ply
# 242-feta-model_mesh_001.ply.ply
# 241-feta-model_mesh_001.ply.ply
# 240-feta-model_mesh_001.ply.ply
# 239-feta-model_mesh_001.ply.ply
# 238-feta-model_mesh_001.ply.ply
# 237-feta-model_mesh_001.ply.ply
# 236-feta-model_mesh_001.ply.ply
# 235-feta-model_mesh_001.ply.ply
# 234-feta-model_mesh_001.ply.ply
# 233-feta-model_mesh_001.ply.ply
# 232-feta-model_mesh_001.ply.ply
# 231-feta-model_mesh_001.ply.ply
# 230-feta-model_mesh_001.ply.ply
# 229-feta-model_mesh_001.ply.ply
# 228-feta-model_mesh_001.ply.ply
# 227-feta-model_mesh_001.ply.ply
# 226-feta-model_mesh_001.ply.ply
# 225-feta-model_mesh_001.ply.ply
# 224-feta-model_mesh_001.ply.ply
# 223-feta-model_mesh_001.ply.ply
# 222-feta-model_mesh_001.ply.ply
# 221-feta-model_mesh_001.ply.ply
# 220-feta-model_mesh_001.ply.ply
# 219-feta-model_mesh_001.ply.ply
# 218-feta-model_mesh_001.ply.ply
# 217-feta-model_mesh_001.ply.ply
# 216-feta-model_mesh_001.ply.ply
# 215-feta-model_mesh_001.ply.ply
# 214-feta-model_mesh_001.ply.ply
# 213-feta-model_mesh_001.ply.ply
# 212-feta-model_mesh_001.ply.ply
# 211-feta-model_mesh_001.ply.ply
# 210-feta-model_mesh_001.ply.ply
# 209-feta-model_mesh_001.ply.ply
# 208-feta-model_mesh_001.ply.ply
# 207-feta-model_mesh_001.ply.ply
# 206-feta-model_mesh_001.ply.ply
# 205-feta-model_mesh_001.ply.ply
# 204-feta-model_mesh_001.ply.ply
# 203-feta-model_mesh_001.ply.ply
# 202-feta-model_mesh_001.ply.ply
# 201-feta-model_mesh_001.ply.ply
# 200-feta-model_mesh_001.ply.ply
# 199-feta-model_mesh_001.ply.ply
# 198-feta-model_mesh_001.ply.ply
# 197-feta-model_mesh_001.ply.ply
# 196-feta-model_mesh_001.ply.ply
# 195-feta-model_mesh_001.ply.ply
# 194-feta-model_mesh_001.ply.ply
# 193-feta-model_mesh_001.ply.ply
# 192-feta-model_mesh_001.ply.ply
# 191-feta-model_mesh_001.ply.ply
# 190-feta-model_mesh_001.ply.ply
# 189-feta-model_mesh_001.ply.ply
# 188-feta-model_mesh_001.ply.ply
# 187-feta-model_mesh_001.ply.ply
# 186-feta-model_mesh_001.ply.ply
# 185-feta-model_mesh_001.ply.ply
# 184-feta-model_mesh_001.ply.ply
# 183-feta-model_mesh_001.ply.ply
# 182-feta-model_mesh_001.ply.ply
# 181-feta-model_mesh_001.ply.ply
# 180-feta-model_mesh_001.ply.ply
# 179-feta-model_mesh_001.ply.ply
# 178-feta-model_mesh_001.ply.ply
# 177-feta-model_mesh_001.ply.ply
# 176-feta-model_mesh_001.ply.ply
# 175-feta-model_mesh_001.ply.ply
# 174-feta-model_mesh_001.ply.ply
# 173-feta-model_mesh_001.ply.ply
# 172-feta-model_mesh_001.ply.ply
# 171-feta-model_mesh_001.ply.ply
# 170-feta-model_mesh_001.ply.ply
# 169-feta-model_mesh_001.ply.ply
# 168-feta-model_mesh_001.ply.ply
# 167-feta-model_mesh_001.ply.ply
# 166-feta-model_mesh_001.ply.ply
# 165-feta-model_mesh_001.ply.ply
# 164-feta-model_mesh_001.ply.ply
# 163-feta-model_mesh_001.ply.ply
# 162-feta-model_mesh_001.ply.ply
# 161-feta-model_mesh_001.ply.ply
# 160-feta-model_mesh_001.ply.ply
# 159-feta-model_mesh_001.ply.ply
# 158-feta-model_mesh_001.ply.ply
# 157-feta-model_mesh_001.ply.ply
# 156-feta-model_mesh_001.ply.ply
# 155-feta-model_mesh_001.ply.ply
# 154-feta-model_mesh_001.ply.ply
# 153-feta-model_mesh_001.ply.ply
# 152-feta-model_mesh_001.ply.ply
# 151-feta-model_mesh_001.ply.ply
# 150-feta-model_mesh_001.ply.ply
# 149-feta-model_mesh_001.ply.ply
# 148-feta-model_mesh_001.ply.ply
# 147-feta-model_mesh_001.ply.ply
# 146-feta-model_mesh_001.ply.ply
# 145-feta-model_mesh_001.ply.ply
# 144-feta-model_mesh_001.ply.ply
# 143-feta-model_mesh_001.ply.ply
# 142-feta-model_mesh_001.ply.ply
# 141-feta-model_mesh_001.ply.ply
# 140-feta-model_mesh_001.ply.ply
# 139-feta-model_mesh_001.ply.ply
# 138-feta-model_mesh_001.ply.ply
# 137-feta-model_mesh_001.ply.ply
# 136-feta-model_mesh_001.ply.ply
# 135-feta-model_mesh_001.ply.ply
# 134-feta-model_mesh_001.ply.ply
# 133-feta-model_mesh_001.ply.ply
# 132-feta-model_mesh_001.ply.ply
# 131-feta-model_mesh_001.ply.ply
# 130-feta-model_mesh_001.ply.ply
# 129-feta-model_mesh_001.ply.ply
# 128-feta-model_mesh_001.ply.ply
# 127-feta-model_mesh_001.ply.ply
# 126-feta-model_mesh_001.ply.ply
# 125-feta-model_mesh_001.ply.ply
# 124-feta-model_mesh_001.ply.ply
# 123-feta-model_mesh_001.ply.ply
# 122-feta-model_mesh_001.ply.ply
# 121-feta-model_mesh_001.ply.ply
# 120-feta-model_mesh_001.ply.ply
# 119-feta-model_mesh_001.ply.ply
# 118-feta-model_mesh_001.ply.ply
# 117-feta-model_mesh_001.ply.ply
# 116-feta-model_mesh_001.ply.ply
# 115-feta-model_mesh_001.ply.ply
# 114-feta-model_mesh_001.ply.ply
# 113-feta-model_mesh_001.ply.ply
# 112-feta-model_mesh_001.ply.ply
# 111-feta-model_mesh_001.ply.ply
# 110-feta-model_mesh_001.ply.ply
# 109-feta-model_mesh_001.ply.ply
# 108-feta-model_mesh_001.ply.ply
# 107-feta-model_mesh_001.ply.ply
# 106-feta-model_mesh_001.ply.ply
# 105-feta-model_mesh_001.ply.ply
# 104-feta-model_mesh_001.ply.ply
# 103-feta-model_mesh_001.ply.ply
# 102-feta-model_mesh_001.ply.ply
# 101-feta-model_mesh_001.ply.ply
# 100-feta-model_mesh_001.ply.ply
# 99-feta-model_mesh_001.ply.ply
# 98-feta-model_mesh_001.ply.ply
# 97-feta-model_mesh_001.ply.ply
# 96-feta-model_mesh_001.ply.ply
# 95-feta-model_mesh_001.ply.ply
# 94-feta-model_mesh_001.ply.ply
# 93-feta-model_mesh_001.ply.ply
# 92-feta-model_mesh_001.ply.ply
# 91-feta-model_mesh_001.ply.ply
# 90-feta-model_mesh_001.ply.ply
# 89-feta-model_mesh_001.ply.ply
# 88-feta-model_mesh_001.ply.ply
# 87-feta-model_mesh_001.ply.ply
# 86-feta-model_mesh_001.ply.ply
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-bec54bbde928> in <module>()
#      15         print f
#      16         mesh = pymesh.load_mesh("./out_energy/landmarks/fetas/"+f)
# ---> 17         mesh_completo = pymesh.boolean(mesh_completo, mesh , operation="union",engine="auto")
#      18         del mesh
#      19
#
# /usr/local/lib/python2.7/dist-packages/pymesh-0.1-py2.7.egg/pymesh/boolean.pyc in boolean(mesh_1, mesh_2, operation, engine, with_timing, exact_mesh_file)
#      81         engine.compute_intersection();
#      82     elif (operation == "union"):
# ---> 83         engine.compute_union();
#      84     elif (operation == "difference"):
#      85         engine.compute_difference();
#
# /usr/local/lib/python2.7/dist-packages/pymesh-0.1-py2.7.egg/pymesh/swig/PyBoolean.pyc in compute_union(self)
#      87     def get_faces(self): return _PyBoolean.BooleanEngine_get_faces(self)
#      88     def clean_up(self): return _PyBoolean.BooleanEngine_clean_up(self)
# ---> 89     def compute_union(self): return _PyBoolean.BooleanEngine_compute_union(self)
#      90     def compute_intersection(self): return _PyBoolean.BooleanEngine_compute_intersection(self)
#      91     def compute_difference(self): return _PyBoolean.BooleanEngine_compute_difference(self)
#
# RuntimeError: std::bad_alloc
