ids = np.array(data_pca.index)
del data_pca

# %%
filtro = (ids!=113)
x_out_total = x_out_total[filtro]
data_planillas = pd.read_excel("./planilla_colecta.xlsx")
data_planillas = data_planillas[data_planillas['id'].isin(ids)]

data_planillas = data_planillas[filtro]

sexo = data_planillas["sexo"].iloc[:].tolist() 
body_fat_range = data_planillas["Body fat range"].iloc[:].tolist() 
peso = data_planillas["peso"].iloc[:].tolist() 
altura = data_planillas["promedio altura"].iloc[:].tolist()
cint = data_planillas["promedio cir cin"].iloc[:].tolist()
cad = data_planillas["promedio cir cad"].iloc[:].tolist()

# %%
x_out_total.shape
# Out:
# (86, 35)

# %%
def bmi_cal(bmi):
    if 18.5 > bmi:
        return "underfat"
    if 18.5 <= bmi < 25:
        return "healthy"
    if 25 <= bmi < 30:
        return "overfat"
    if 30 <= bmi:
        return "obese"

# %%
bmis =  list(map( lambda pa: bmi_cal(pa[0] / (pa[1]/100*pa[1]/100))  ,zip(peso,altura)))

# %%
interest_feat = range(10)
data = pd.DataFrame(x_out_total)
data["labels"]= bmis
color_wheel = {"healthy": "red", "obese": "blue","overfat":"green","underfat":"black","desconocido":"yellow"}
colors = data["labels"].map(lambda x: color_wheel.get(x.lower()))
pd.scatter_matrix(data.loc[:,interest_feat[:-1]], figsize=(12,8), diagonal='kde',label=data.loc[:,"labels"],c=colors)
plt.show()
del data,color_wheel

# %%
plt.style.use('ggplot')
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 14}

plt.rc('font', **font)
plt.rcParams["figure.figsize"] = [15,10]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x_out_total[:,0],x_out_total[:,1],c=colors,marker="o")

red_patch = mpatches.Patch(color='red', label='healthy')
green_patch = mpatches.Patch(color='green', label='overfat')
blue_patch = mpatches.Patch(color='blue', label='obese')
black_patch = mpatches.Patch(color='black', label='underfat')
plt.legend(handles=[red_patch,blue_patch,green_patch,black_patch])

# for label, x, y in zip(np.array(sorted(ids)), x_out_total[:,0], x_out_total[:,1]):
#     plt.annotate(
#         label,
#         xy=(x, y), xytext=(-20, 20),
#         textcoords='offset points', ha='right', va='bottom',
#         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
#         arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.legend(loc='best')
plt.title("Female Sample - BMI")
ax.set_xlabel("PCA - 1")
ax.set_ylabel("PCA - 2")
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
data_planillas
# Out:
#       id fecha de colecta sexo                 edad   peso  altura 1  \
# 0      1       2016-07-11    f                  NaN   62.3     163.4
# 1      2       2016-07-11    f                  NaN   81.3     169.9
# 3      4       2016-07-11    f                  NaN   64.7     172.3
# 4      5       2016-07-11    f                  NaN   64.1     166.0
# 8      9       2016-07-11    f                  NaN   63.8     167.6
# 9     10       2016-07-11    f                  NaN   67.6     160.6
# 10    11       2016-07-11    f                  NaN   50.6     155.0
# 15    16       2016-07-13    f  1970-11-14 00:00:00   97.4     160.4
# 16    17       2016-07-13    f  1941-01-08 00:00:00   64.3     158.2
# 19    20       2016-07-13    f  1982-02-14 00:00:00   58.7     166.1
# 20    21       2016-07-13    f  1981-08-02 00:00:00   50.7     156.6
# 23    24       2016-07-13    f  1971-12-04 00:00:00   61.7     158.8
# 24    25       2016-07-13    f  1991-03-25 00:00:00   58.8     164.1
# 34    35       2016-07-15    f  1978-12-23 00:00:00   51.2     148.4
# 147  148       2016-08-26    f  1973-05-19 00:00:00   72.1     162.1
# 149  150       2016-08-26    f  1981-09-11 00:00:00   57.5     146.0
# 150  151       2016-08-26    f  1979-01-21 00:00:00   46.9     152.0
# 153  154       2016-08-26    f  1985-10-08 00:00:00   64.3     169.5
#
#      altura 2  promedio altura  cir cin 1  cir cin 2  \
# 0       163.4           163.40      90.08      90.02
# 1       169.3           169.60     106.00     106.40
# 3       172.3           172.30      87.00      87.20
# 4       166.2           166.10      81.00      81.60
# 8       167.5           167.60      83.70      84.00
# 9       160.5           160.55      97.80      98.00
# 10      155.0           155.00      78.30      78.00
# 15      160.5           160.50     103.00     103.40
# 16      158.2           158.20      92.70      93.00
# 19      166.0           166.10      81.90      81.70
# 20      156.7           156.70      78.00      78.70
# 23      158.5           158.70      91.00      91.30
# 24      164.4           164.30      84.30      84.70
# 34      148.4           148.40      78.50      78.70
# 35      160.4           160.40      71.80      72.00
# 37      153.2           153.30      81.30      81.00
# 38      155.1           155.10      76.80      76.50
# 40      156.0           156.00      79.50      79.30
# 41      155.0           155.10      85.00      85.40
# 42      158.3           158.30      99.00      99.30
# 43      165.4           165.40      84.50      84.40
# 46      155.0           155.10      81.00      81.30
# 47      170.1           170.10      80.60      81.00
# 48      157.4           157.50      96.50      97.00
# 49      163.2           163.10     109.70     110.00
# 50      162.0           161.90      95.50      95.60
# 51      161.6           161.60      76.20      76.00
# 52      155.5           155.50     100.00     100.00
# 53      158.2           158.10      89.80      89.00
# 55      177.3           176.90      87.00      87.90
# ..        ...              ...        ...        ...
# 100     161.6           161.70      85.60      85.80
# 102     158.7           158.75      83.00      83.20
# 103     160.5           160.45      92.00      91.80
# 105     162.5           162.70     118.30     119.30
# 106       NaN           156.50      81.60      82.30
# 113     155.5           155.40      82.60      82.40
# 114     155.9           155.80      92.40      92.00
# 116     162.9           163.00      91.00      91.70
# 117     149.7           149.60      92.60      92.00
# 119     154.3           154.30      98.70      98.00
# 120     167.8           167.90      88.90      88.00
# 122     152.2           152.50      83.00      83.30
# 123     161.4           161.20     111.30     111.00
# 124     160.5           160.50      86.70      86.80
# 126     151.2           151.20      76.00      77.50
# 127     155.3           155.30      73.00      73.20
# 129     156.0           155.90      91.00      91.90
# 134     160.0           160.00      86.80      87.00
# 135     156.5           156.40      76.80      78.00
# 136     156.3           156.40      82.60      83.00
# 137     158.6           158.60      74.00      74.60
# 138     166.4           166.40     103.00     103.40
# 140     169.3           169.20      88.80      88.00
# 142     154.3           154.20     103.00     103.60
# 144     150.6           150.60      71.00      71.90
# 146     165.7           165.60      93.00      93.90
# 147     161.8           162.00     101.00     101.30
# 149     145.8           145.90     100.50     100.70
# 150     152.3           152.20      80.70      80.00
# 153     169.1           169.30      88.20      88.50
#
#                            ...                          Mass  Body fat range  \
# 0                          ...                          19.5         Healthy
# 1                          ...                          33.3           Obese
# 3                          ...                          18.4         Healthy
# 4                          ...                          14.6         Healthy
# 8                          ...                          15.1         Healthy
# 9                          ...                          21.4         Healthy
# 10                         ...                           7.1        Underfat
# 15                         ...                          45.3           Obese
# 16                         ...                          15.7         Healthy
# 19                         ...                           6.5        Underfat
# 20                         ...                           9.5        Underfat
# 23                         ...                          20.5         Healthy
# 24                         ...                          17.6         Healthy
# 34                         ...                          11.8         Healthy
# 35                         ...                          12.2         Healthy
# 37                         ...                          15.1         Healthy
# 38                         ...                          14.0         Healthy
# 40                         ...                           9.5        Underfat
# 41                         ...                          12.0        Underfat
# 42                         ...                          26.7         overfat
# 43                         ...                          13.6         Healthy
# 46                         ...                          14.1         Healthy
# 47                         ...                          14.8         Healthy
# 48                         ...                          29.4         overfat
# 49                         ...                          34.2           Obese
# 50                         ...                          29.6         overfat
# 51                         ...                          11.8         Healthy
# 52                         ...                          30.7           Obese
# 53                         ...                          17.1         Healthy
# 55                         ...                          11.8         Healthy
# ..                         ...                           ...             ...
# 100                        ...                          19.2         Healthy
# 102                        ...                          15.3         Healthy
# 103                        ...                          20.2         Healthy
# 105                        ...                          58.0           Obese
# 106                        ...                          17.0         Healthy
# 113                        ...                          15.3         Healthy
# 114                        ...                          26.9         overfat
# 116                        ...                          20.0         Healthy
# 117                        ...                          24.6         overfat
# 119                        ...                          24.5         overfat
# 120                        ...                          23.7         overfat
# 122                        ...                          17.7         Healthy
# 123                        ...                          35.3           obese
# 124                        ...                          14.3         Healthy
# 126                        ...                          13.4         Healthy
# 127                        ...                           7.1        underfat
# 129                        ...                          24.0         overfat
# 134                        ...                          17.3         Healthy
# 135                        ...                          13.4         Healthy
# 136                        ...                          15.7         Healthy
# 137                        ...                           7.4        Underfat
# 138                        ...                          32.4           Obese
# 140                        ...                          20.5         Healthy
# 142                        ...                          29.9           Obese
# 144                        ...                          10.9        Underfat
# 146                        ...                          28.9           Obese
# 147                        ...                          28.3         overfat
# 149                        ...                          19.1         overfat
# 150                        ...                          10.0         Healthy
# 153                        ...                          20.2         Healthy
#
#      Fat free mass  Body water%  Mass.1  Muscle mass       observaciones  \
# 0             42.8         51.0    31.8         40.7                 NaN
# 1             47.9         42.2    34.3         45.4                 NaN
# 3             46.3         50.0    32.3         44.0                 NaN
# 4             49.5         55.0    35.3         46.9                 NaN
# 8             48.7         53.7    34.3         46.3                 NaN
# 9             46.2         48.3    32.7         43.8  embarazada 5 meses
# 10            43.5         59.3    30.0         41.2                 NaN
# 15            52.1         38.6    37.6         49.4                 NaN
# 16            48.6         51.7    33.2         46.1                 NaN
# 19            52.2         61.7    36.2         49.7                 NaN
# 20            41.2         55.6    28.2         39.0                 NaN
# 23            41.2         46.1    28.4         39.0                 NaN
# 24            41.2         48.8    28.7         39.0                 NaN
# 34            39.4         54.9    28.1         37.4                 NaN
# 35            44.5         55.3    31.4         42.2                 NaN
# 37            40.5         50.0    27.8         38.5                 NaN
# 38            42.6         52.2    29.5         40.4                 NaN
# 40            40.8         57.8    29.1         38.7                 NaN
# 41            41.2         54.5    29.0         39.0                 NaN
# 42            40.2         41.7    27.9         38.2                 NaN
# 43            39.7         51.4    27.4         37.6                 NaN
# 46            37.8         50.5    26.2         35.9                 NaN
# 47            50.9         55.0    36.1         48.3                 NaN
# 48            45.7         42.4    31.8         43.3                 NaN
# 49            45.5         40.9    32.6         43.2                 NaN
# 50            47.1         43.7    33.5         44.7                 NaN
# 51            41.2         54.7    29.0         39.1                 NaN
# 52            44.3         42.0    31.5         42.1                 NaN
# 53            38.7         47.7    26.6         36.6                 NaN
# 55            55.6         55.9    37.7         52.8                 NaN
# ..             ...          ...     ...          ...                 ...
# 100           39.2         45.8    26.7         37.2                 NaN
# 102           39.8         49.7    27.4         37.8                 NaN
# 103           41.3         46.8    28.8         39.3                 NaN
# 105           58.0         36.9    42.8         55.1                 NaN
# 106           42.2         49.7    29.4         40.0                 NaN
# 113           38.9         48.8    26.4          NaN                 NaN
# 114           44.8         44.0    31.5         42.5                 NaN
# 116           45.1         48.1    31.3         42.8                 NaN
# 117           41.4         43.9    29.0         39.3                 NaN
# 119           40.3         42.7    27.7         38.2                 NaN
# 120           42.3         44.4    29.3         40.2                 NaN
# 122           42.1         48.9    29.2         40.0                 NaN
# 123           49.9         41.9    35.7         47.4                 NaN
# 124           42.6         51.8    29.5         40.4                 NaN
# 126           39.9         51.5    27.4         27.9                 NaN
# 127           39.9         57.5    27.0         37.9                 NaN
# 129           41.5         44.0    28.8         39.4                 NaN
# 134           43.3         51.3    31.1         41.1                 NaN
# 135           40.6         51.7    27.9         38.5                 NaN
# 136           45.9         53.7    33.1         43.5                 NaN
# 137           36.9         56.5    25.0         35.0                 NaN
# 138           47.5         42.5    34.0         45.1                 NaN
# 140           45.2         50.1    32.9         42.9                 NaN
# 142           41.2         39.7    28.2         39.1                 NaN
# 144           37.2         52.4    25.2         35.3                 NaN
# 146           44.8         43.0    31.7         42.5                 NaN
# 147           43.8         42.7    30.8         41.6                 NaN
# 149           38.4         46.2    26.6         36.5                 NaN
# 150           36.9         53.2    25.0         35.0                 NaN
# 153           44.1         48.1    30.9         41.9                 NaN
#
#                                               Contacto                  Pass  \
# 0                          antonelamartelli@gmail.com   57bb4cc873976eefb09c
# 1                                  rociocnp@gmail.com   134e95c44f5a8170be99
# 3                               sildermolen@gmail.com   b7758641cf800c1a1b41
# 4    https://www.facebook.com/fiorella.malaspina?hc...  28c90e52684e18c75395
# 8                      soulages@cenpat-conicet.gob.ar   44967cf45cc5980fe427
# 9                   ailenchalco@cenpat-conicet.gob.ar   4b4504aab75fb387408f
# 10                      gtorchio@cenpat-conicet.gob.ar  c81b4d67c432bc7135c9
# 15                              cenzano@cenpat.edu.ar   786dcca49788ecb07912
# 16                              cenzano@cenpat.edu.ar   a86fb8b0d47f1df53d6c
# 19   malaurq@gmail.com , rojasquiroga@cenpat-conice...  7f682b7d9664af059e9b
# 20                              agomezlaich@gmail.com   7b67869b8d6976993331
# 23                        alexa@cenpat-conicet.gob.ar   e2974f228e3c0431c0d3
# 24                   rominaguadalupekrebs@hotmail.com   da83d3d7a0551ee104f1
# 34                             mariana_ptm@hotmail.com  d84a244ef45caf11f6ab
# 35                natalia@safetyintegralsolutions.com   1eba7b7100704f5a6412
# 37                             madryncris@yahoo.com.ar  b241f0df0f213353a35f
#
#                                                   link
# 0    https://sketchfab.com/models/37e9a098625f4db59...
# 1    https://sketchfab.com/models/de328f80141640379...
# 3    https://sketchfab.com/models/588f801eb8064e88a...
# 4    https://sketchfab.com/models/dcc0886c45c04c87b...
# 8    https://sketchfab.com/models/923799e591ab4bd49...
# 9    https://sketchfab.com/models/0e0b6318450540aab...
# 10   https://sketchfab.com/models/6b6bb6fb754b495ba...
# 15   https://sketchfab.com/models/717f879be4ae49d2b...
# 16   https://sketchfab.com/models/d429e8007e434d7d9...
# 19   https://sketchfab.com/models/bd9633788cf14b6db...
# 20   https://sketchfab.com/models/ea6cbc15bbb04f07a...
# 23   https://sketchfab.com/models/05f538a2341542469...
# 24   https://sketchfab.com/models/176f1cb92ef74670b...
# 34   https://sketchfab.com/models/e26f9027184e4acf9...
# 35   https://sketchfab.com/models/bc9906de10a8463ba...
# 37   https://sketchfab.com/models/e55c087f9f5c49269...
# 38   https://sketchfab.com/models/88babf9ee6df42d2b...
# 40   https://sketchfab.com/models/736791d929654a0cb...
# 41   https://sketchfab.com/models/f104f64b67db49f8b...
# 42   https://sketchfab.com/models/5052035fdd0e4ab99...
# 43   https://sketchfab.com/models/28d91fbe824c4f08b...
# 46   https://sketchfab.com/models/e01e9ec4758645849...
# 47   https://sketchfab.com/models/cac4db8bd0904b60a...
# 48   https://sketchfab.com/models/397e674d55844f669...
# 49   https://sketchfab.com/models/e173257e2ca04018a...
# 50   https://sketchfab.com/models/5575df7fc1fe4c799...
# 51   https://sketchfab.com/models/c51f5258d105481f9...
# 52   https://sketchfab.com/models/caa941126d0f43909...
# 53   https://sketchfab.com/models/2dfd41195ba84a9fb...
# 55   https://sketchfab.com/models/e0daa85944b04323b...
# ..                                                 ...
# 100  https://sketchfab.com/models/e8a1b395dc6641a68...
# 102  https://sketchfab.com/models/20095a27701c444eb...
# 103  https://sketchfab.com/models/4c4012e6bd8b43ae8...
# 105  https://sketchfab.com/models/8a2cafb10c094dc2a...
# 106  https://sketchfab.com/models/b06050d254dd44c3a...
# 113  https://sketchfab.com/models/106cfa7890e34f7c8...
# 114  https://sketchfab.com/models/cb287bd917f14a4a8...
# 116  https://sketchfab.com/models/bba37611f2c74755b...
# 117  https://sketchfab.com/models/52fb97c1baf549fe8...
# 119  https://sketchfab.com/models/063d8b6232ad48628...
# 120  https://sketchfab.com/models/0fe481314d7347e88...
# 122  https://sketchfab.com/models/67d16362e5d74a2c8...
# 123  https://sketchfab.com/models/be5deeaf28b54b56a...
# 124  https://sketchfab.com/models/5bb64d1eac3f49e58...
# 126  https://sketchfab.com/models/37b9e542034f4035b...
# 127  https://sketchfab.com/models/10fa2c4646ac430e9...
# 129  https://sketchfab.com/models/cbd5db5123534a03a...
# 134  https://sketchfab.com/models/fd307573778c47c28...
# 135  https://sketchfab.com/models/563b37108d8f454e9...
# 136  https://sketchfab.com/models/a0fe3c01518147ae9...
# 137  https://sketchfab.com/models/259ac3e0b4934cb2a...
# 138                                                NaN
# 140  https://sketchfab.com/models/584b7a2dd33b43ffb...
# 142  https://sketchfab.com/models/841cfcf341ee44a9a...
# 144  https://sketchfab.com/models/5150a36ef6d84342b...
# 146  https://sketchfab.com/models/7b2a0fc0701b451f8...
# 147  https://sketchfab.com/models/79b37bcabf5943e09...
# 149  https://sketchfab.com/models/64833d51a7524cd49...
# 150  https://sketchfab.com/models/db420d11070d4a1a8...
# 153  https://sketchfab.com/models/da0f1c28e1884e228...
#
# [86 rows x 49 columns]

# %%
fat_free_mass = np.array(data_planillas["Fat free mass"])

# %%
#fat_free_mass = fat_free_mass[filtro]

# %%
x = x_out_total[:,0] 
y = fat_free_mass
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('Fat Free Mass')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')

# for label, x, y in zip(np.array(sorted(ids)), x, y):
#     plt.annotate(
#         label,
#         xy=(x, y), xytext=(-20, 20),
#         textcoords='offset points', ha='right', va='bottom',
#         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
#         arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.grid(True)
plt.show()
# Out:
# r-squared: 0.043509451487405384
# p-value: 0.05393873943423355
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
body_fat_porcent = np.array(data_planillas["Body fat%"])

# %%
#body_fat_porcent = body_fat_porcent[filtro]

# %%
x = x_out_total[:,0] 
y = body_fat_porcent
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('Body Fat %')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.4638313893594965
# p-value: 5.374378607619499e-13
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
mass = np.array(data_planillas["Mass.1"])
#mass = mass[filtro]
x = x_out_total[:,0] 
y = mass
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('Mass')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.04725152567104875
# p-value: 0.04438297026030235
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
bmi = list(map( lambda pa: (pa[0] / (pa[1]/100 *pa[1]/100))  ,zip(peso,altura)))
bmi = np.array(bmi)#[filtro]
x = x_out_total[:,0] 
y = bmi
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('BMI')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.48020292245271673
# p-value: 1.4371707804634087e-13
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ict = np.array(cint)/np.array(altura)
ict = np.array(ict)#[filtro]
x = x_out_total[:,0] 
y = ict
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('ICT')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.6334201448055158
# p-value: 5.3686711262351684e-20
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
icc = np.array(cint)/np.array(cad)
icc = np.array(icc)#[filtro]
x = x_out_total[:,0] 
y = icc
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-0')
plt.ylabel('ICC')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.4136591315510043
# p-value: 2.4299783306163843e-11
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
muscle_mass = np.array(data_planillas["Muscle mass"])
muscle_mass = muscle_mass#[filtro]
muscle_mass[muscle_mass.argmin()] = 0
filtro_muscle = muscle_mass != 0
x = x_out_total[:,0]
x = x[filtro_muscle]
y = muscle_mass[np.array(filtro_muscle)]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("r-squared: {}".format(r_value**2))
print("p-value: {}".format(p_value))
plt.plot(x , y,".")
plt.xlabel('PCA-1')
plt.ylabel('Muscle Mass')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.grid(True)
plt.show()
# Out:
# r-squared: 0.03681154252217067
# p-value: 0.07856327000191772
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.rcParams["figure.figsize"] = [15,10]
fig = plt.figure()
ax = fig.add_subplot(111)
s = ax.scatter(x_out_total[:,0],x_out_total[:,1],c=icc,marker="o",cmap=plt.cm.Spectral_r,vmax=icc.min(),vmin=icc.max())
cbar = plt.colorbar(mappable=s)
cbar.set_label('ICC')
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.rcParams["figure.figsize"] = [15,10]
fig = plt.figure()
ax = fig.add_subplot(111)
s = ax.scatter(x_out_total[:,0],x_out_total[:,1],c=bmi,marker="o",cmap=plt.cm.Spectral_r,vmax=bmi.min(),vmin=bmi.max())
cbar = plt.colorbar(mappable=s)
cbar.set_label("BMI")
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
